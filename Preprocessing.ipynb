# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## 2014

# %%
data = pd.read_csv("data/stsal_2014.csv")
data.shape
# Out:
# (747, 30)

# %%
data = data[lambda x: x.Salary > 0]
data = data.reset_index(drop=True)

data.shape
# Out:
# (480, 30)

# %%
def g_sum(index):
    name = data.iloc[index]['Name']
    
    sum = data.iloc[index]['G']
    
    for i in range(index+1, len(data)):
        if data.iloc[i]['Name'] == name:
            sum += data.iloc[i]['G']
            
    return sum

# %%
i = 0
while i < len(data):
    name = data.loc[i,'Name']
    gamesum = g_sum(i)
    
    for j in range(17, 22):
        data.iloc[i,j] = data.loc[i,'G'] * data.iloc[i,j]
    
    k = i + 1
    while k < len(data):
        if data.loc[k,'Name'] == name:
            
            if data.loc[k,'Tm'] not in data.loc[i,'Tm']:
                data.loc[i,'Tm'] = data.loc[i,'Tm'] + "/" + data.loc[k,'Tm']
            if data.loc[k,'Lg'] not in data.loc[i,'Lg']:
                data.loc[i,'Lg'] = data.loc[i,'Lg'] + "/" + data.loc[k,'Lg']
            
            for l in range(4, 17):
                data.iloc[i,l] += data.iloc[k,l]
                
            for m in range(17, 22):
                data.iloc[i,m] += data.loc[k,'G'] * data.iloc[k,m]
            
            for n in range(22, 28):
                data.iloc[i,n] += data.iloc[k,n]
                
            data.loc[i,'Salary'] += data.loc[k,'Salary']
            
            data = data.drop(data.index[k]).reset_index(drop=True)
        
        else:
            k += 1
            
    for o in range(17, 22):
        data.iloc[i,o] = data.iloc[i,o] / gamesum
    
    i += 1

# %%
data
# Out:
#                                Name   Age           Tm         Lg    G   PA  \
# 0              Jose Abreu\abreujo02  27.0          CHW         AL  145  622
# 1             Tony Abreu#\abreuto01  29.0          SFG         NL    3    4
# 2          Dustin Ackley*\ackledu01  26.0          SEA         AL  143  542
# 3             Matt Adams*\adamsma01  25.0          STL         NL  142  563
# 4             Jim Adduci*\adducji02  29.0          TEX         AL   44  114
# 5         Ehire Adrianza#\adriaeh01  24.0          SFG         NL   53  106
# 6          Zoilo Almonte#\almonzo01  25.0          NYY         AL   13   36
# 7          Yonder Alonso*\alonsyo01  27.0          SDP         NL   84  288
# 8             Jose Altuve\altuvjo01  24.0          HOU         AL  158  707
# 9          Pedro Alvarez*\alvarpe01  27.0          PIT         NL  122  445
# 10        Alexi Amarista*\amarial01  25.0          SDP         NL  148  466
# 11           Elvis Andrus\andruel01  25.0          TEX         AL  157  685
# 12              Nori Aoki*\aokino01  32.0          KCR         AL  132  549
# 13         Oswaldo Arcia*\arciaos01  23.0          MIN         AL  103  410
# 14          Nolan Arenado\arenano01  23.0          COL         NL  111  467
# 15          Joaquin Arias\ariasjo01  29.0          SFG         NL  107  204
# 16   Erisbel Arruebarrena\arrueba01  24.0          LAD         NL   22   45
# 17            Cody Asche*\ascheco01  24.0          PHI         NL  121  434
# 18            Alex Avila*\avilaal01  27.0          DET         AL  124  457
# 19            Mike Aviles\avilemi01  33.0          CLE         AL  113  374
# 20           Erick Aybar#\aybarer01  30.0          LAA         AL  156  642
# 390  263   31   55  13  ...  0.620000   75.000000   93    4    2   4   1    1
# 391  269   26   75  10  ...  0.752000  113.000000  116    2    1   0   1    2
# 392  220   32   56  16  ...  0.799000  125.000000   90    5    3   0   2    2
# 393  512   74  139  25  ...  0.809000  126.000000  239   12   11   1   2    2
# 394   74   16   22   6  ...  0.808000  126.088235   32    2    2   4   2    0
# 395  252   36   69  19  ...  0.809000  123.000000  114    7    8   0   1    0
# 396  534   85  156  37  ...  0.849000  134.000000  243    9    9   0   3    3
# 397   56    6   13   2  ...  0.656000   72.000000   21    1    0   0   3    0
# 398  104   13   32   5  ...  0.839000  132.000000   52    1    0   0   2    0
# 399  594   96  128  20  ...  0.743043  108.847826  236   12   18   0  10    6
# 400  402   52  100  14  ...  0.680000   89.000000  156   12    4   5   1    3
# 401  535   54  144  30  ...  0.698000  101.000000  200   22    4   0   5    5
# 402  582   94  165  30  ...  0.764000  115.000000  234    9    3   3   2    3
# 403  650   80  144  40  ...  0.681986   94.630631  250    6   10   2   6    4
# 404  280   48   64  10  ...  0.610000   77.000000   87    2    5   5   2    1
# 405  214   26   60  19  ...  0.790000  117.000000   96    6    0   0   4    0
# 406  570   83  155  34  ...  0.749000  116.000000  225    8    1   2   6    4
# 407  438   51   87  20  ...  0.658000   88.000000  177   12   17   0   4    1
#
#      Pos Summary    Salary
# 0            *3D   7000000
# 1            /45    745000
# 2           *7/D   1700000
# 3             *3    516000
# 4          7/9D3    501000
# 5           4/65    500500
# 6           /79D    511300
# 7            3/5    980000
# 8           *4/D   1250000
# 9           5/3D   4250000
# 10        6548/7    511100
# 11          *6/D   6475000
# 12         *9/D7   1950000
# 13           9/D    512500
# 14            *5    500000
# 15        5346/D   1150000
# 16             6   3000000
# 17            *5    500000
# 18         *2/3D   4150000
# 19       5476/89   3500000
# 20            *6   8500000
# 21          34/5   1600000
# 22         64/35   2000000
# 23         97/8D    501000
# 24           /7D   1000000
# 25             3   1250000
# 26         *9D38  14000000
# 27            /7    700000
# 28         45/6D  12525000
# 29           3/9   2900000
# ..           ...       ...
# 378        564/3   1000000
# 379            4  39000000
# 380         *7/D  14250000
# 381           *8  13450000
# 382            5   6500000
# 383        *4/3D  15000000
# 384        *54/D   1710000
# 385        53/4D   3195000
# 386         7389    507500
# 387        *89/7   4250000
# 388       *97D/3   2800000
# 389            9  13000000
# 390          6/D    503800
# 391       392/D7    502500
# 392            3  12000000
# 393           *4   5750000
# 394         /46D   1545000
# 395          4/D  11000000
# 396         *9/D  20000000
# 397          5/3    500000
# 398          2/D   7700000
# 399         7D/9  21000000
# 400            4    500000
# 401           *5  20000000
# 402          *78    505000
# 403        78/9D  21750000
# 404        7/48D   1850000
# 405        75/3D  14000000
# 406      4769/D8   7000000
# 407         *2/D    504100
#
# [408 rows x 30 columns]

# %%
data.shape
# Out:
# (408, 30)

# %%
data.to_csv("data_preprocessing/data_preprocessing_2014.csv")

# %% [markdown]
# ## 2015

# %%
data = pd.read_csv("data/stsal_2015.csv")
data.shape
# Out:
# (738, 30)

# %%
data = data[lambda x: x.Salary > 0]
data = data.reset_index(drop=True)

data.shape
# Out:
# (445, 30)

# %%
i = 0
while i < len(data):
    name = data.loc[i,'Name']
    gamesum = g_sum(i)
    
    for j in range(17, 22):
        data.iloc[i,j] = data.loc[i,'G'] * data.iloc[i,j]
    
    k = i + 1
    while k < len(data):
        if data.loc[k,'Name'] == name:
            
            if data.loc[k,'Tm'] not in data.loc[i,'Tm']:
                data.loc[i,'Tm'] = data.loc[i,'Tm'] + "/" + data.loc[k,'Tm']
            if data.loc[k,'Lg'] not in data.loc[i,'Lg']:
                data.loc[i,'Lg'] = data.loc[i,'Lg'] + "/" + data.loc[k,'Lg']
            
            for l in range(4, 17):
                data.iloc[i,l] += data.iloc[k,l]
                
            for m in range(17, 22):
                data.iloc[i,m] += data.loc[k,'G'] * data.iloc[k,m]
            
            for n in range(22, 28):
                data.iloc[i,n] += data.iloc[k,n]
                
            data.loc[i,'Salary'] += data.loc[k,'Salary']
            
            data = data.drop(data.index[k]).reset_index(drop=True)
        
        else:
            k += 1
            
    for o in range(17, 22):
        data.iloc[i,o] = data.iloc[i,o] / gamesum
    
    i += 1

# %%
data
# Out:
#                                 Name   Age           Tm         Lg    G   PA  \
# 0               Jose Abreu\abreujo02  28.0          CHW         AL  154  668
# 1           Dustin Ackley*\ackledu01  27.0  TOT/SEA/NYY         AL  216  528
# 2              Matt Adams*\adamsma01  26.0          STL         NL   60  186
# 3               Nick Ahmed\ahmedni01  25.0          ARI         NL  134  459
# 4     Arismendy Alcantara#\alcanar01  23.0          CHC         NL   11   32
# 5           Yonder Alonso*\alonsyo01  28.0          SDP         NL  103  402
# 6              Jose Altuve\altuvjo01  25.0          HOU         AL  154  689
# 7           Pedro Alvarez*\alvarpe01  28.0          PIT         NL  150  491
# 8             Elvis Andrus\andruel01  26.0          TEX         AL  160  661
# 9                Nori Aoki*\aokino01  33.0          SFG         NL   93  392
# 10          Oswaldo Arcia*\arciaos01  24.0          MIN         AL   19   65
# 11           Nolan Arenado\arenano01  24.0          COL         NL  157  665
# 12           Joaquin Arias\ariasjo01  30.0          SFG         NL   40   59
# 13             Cody Asche*\ascheco01  25.0          PHI         NL  129  456
# 14             Alex Avila*\avilaal01  28.0          DET         AL   67  219
# 15             Mike Aviles\avilemi01  34.0          CLE         AL   98  317
# 16            Erick Aybar#\aybarer01  31.0          LAA         AL  156  638
# 17              Jeff Baker\bakerje03  34.0          MIA         NL   41   80
# 18            Clint Barmes\barmecl01  36.0          SDP         NL   98  224
# 19           Darwin Barney\barneda01  29.0  TOT/LAD/TOR  MLB/NL/AL   34   60
# 20           Jose Bautista\bautijo02  34.0          TOR         AL  153  666
# 21          Gordon Beckham\beckhgo01  28.0          CHW         AL  100  237
# 22             Tim Beckham\beckhti01  25.0          TBR         AL   82  223
# 23            Brandon Belt*\beltbr01  27.0          SFG         NL  137  556
# 24         Carlos Beltran#\beltrca01  38.0          NYY         AL  133  531
# 367  543   69  146  32  ...  0.756000  106.000000  232    9    8   0   8    5
# 368   30    0    4   0  ...  0.267000  -28.000000    4    0    0   0   0    0
# 369   84    7   14   1  ...  0.513000   46.000000   21    3    2   0   0    0
# 370  331   51   73  16  ...  0.685000   85.000000  127    8    3   0   6    0
# 371  258   24   69  14  ...  0.742000  101.000000  109    4    0   0   3    0
# 372  264   16   50  10  ...  0.500625   38.491071   66    2    2   4   2    0
# 373  557   71  146  28  ...  0.707000   93.000000  215   10   15   0   5    2
# 374  152   24   44   7  ...  0.814000  126.000000   66    4    0   0   0    0
# 375  476   63  143  30  ...  0.782000  118.000000  198   13    2   0   0    2
# 376  318   53   80  20  ...  0.773000  109.000000  144    6    3   3   2    2
# 377  174   20   47   6  ...  0.628000   71.000000   59    8    1   0   1    0
# 378  170   32   26   8  ...  0.416604   16.339623   42    2    2   4   0    2
# 379  346   43   86  25  ...  0.773000  107.000000  161   13    1   0  10    0
# 380  350   28   61  11  ...  0.530000   48.000000  105    6    5   8   2    0
#
#      Pos Summary    Salary
# 0            *3D   8666000
# 1        784/3D9   7800000
# 2              3    534000
# 3             *6    508500
# 4            /45    510000
# 5            3/5   1650000
# 6           *4/D   2500000
# 7           *3/D   5750000
# 8             *6  15000000
# 9           7/9D   4000000
# 10           7/9    532500
# 11            *5    512500
# 12        /5634D   1450000
# 13            75    517500
# 14          23/D   5400000
# 15      7564/8D9   3500000
# 16          *6/D   8500000
# 17        3/45D7   2100000
# 18           6/3   1300000
# 19          4/56   7575000
# 20           *9D  14000000
# 21         54/6D   2000000
# 22         46D/5    508100
# 23           *37   3600000
# 24          *9/D  15000000
# 25          *5/D  16000000
# 26             2    507500
# 27         *89/D    514500
# 28         *87/9    517500
# 29         546/3    850000
# ..           ...       ...
# 351            2   1750000
# 352        4/679    517300
# 353       95/73D   5500000
# 354         *8/D   6083000
# 355        53/46   2500000
# 356         4/3D    507500
# 357         *7/D  14500000
# 358            8  14450000
# 359        53/D4   4200000
# 360      57/394D   5025000
# 361       793/8D    522500
# 362           D3    517500
# 363         *879  12750000
# 364         97/8  39000000
# 365         23/D    512500
# 366           *3  14000000
# 367           *4   8000000
# 368       /74569    509600
# 369           7D   2000000
# 370         79/D  21000000
# 371         2D/3   8300000
# 372          2/D   2100000
# 373           *4    520000
# 374            5  20000000
# 375          *78    570000
# 376       *978/D   2500000
# 377         9/D7   2250000
# 378         78/9   3000000
# 379          3/7  14000000
# 380           *2    523500
#
# [381 rows x 30 columns]

# %%
data.shape
# Out:
# (381, 30)

# %%
data.to_csv("data_preprocessing/data_preprocessing_2015.csv")

# %% [markdown]
# ## 2016

# %%
data = pd.read_csv("data/stsal_2016.csv")
data.shape
# Out:
# (703, 30)

# %%
data = data[lambda x: x.Salary > 0]
data = data.reset_index(drop=True)

data.shape
# Out:
# (393, 30)

# %%
i = 0
while i < len(data):
    name = data.loc[i,'Name']
    gamesum = g_sum(i)
    
    for j in range(17, 22):
        data.iloc[i,j] = data.loc[i,'G'] * data.iloc[i,j]
    
    k = i + 1
    while k < len(data):
        if data.loc[k,'Name'] == name:
            
            if data.loc[k,'Tm'] not in data.loc[i,'Tm']:
                data.loc[i,'Tm'] = data.loc[i,'Tm'] + "/" + data.loc[k,'Tm']
            if data.loc[k,'Lg'] not in data.loc[i,'Lg']:
                data.loc[i,'Lg'] = data.loc[i,'Lg'] + "/" + data.loc[k,'Lg']
            
            for l in range(4, 17):
                data.iloc[i,l] += data.iloc[k,l]
                
            for m in range(17, 22):
                data.iloc[i,m] += data.loc[k,'G'] * data.iloc[k,m]
            
            for n in range(22, 28):
                data.iloc[i,n] += data.iloc[k,n]
                
            data.loc[i,'Salary'] += data.loc[k,'Salary']
            
            data = data.drop(data.index[k]).reset_index(drop=True)
        
        else:
            k += 1
            
    for o in range(17, 22):
        data.iloc[i,o] = data.iloc[i,o] / gamesum
    
    i += 1

# %%
data
# Out:
#                             Name   Age                   Tm         Lg    G  \
# 0           Jose Abreu\abreujo02  29.0                  CHW         AL  159
# 1       Dustin Ackley*\ackledu01  28.0                  NYY         AL   28
# 2    Cristhian Adames#\adamecr01  24.0                  COL         NL  121
# 3          Matt Adams*\adamsma01  27.0                  STL         NL  118
# 4      Ehire Adrianza#\adriaeh01  26.0                  SFG         NL   40
# 5           Nick Ahmed\ahmedni01  26.0                  ARI         NL   90
# 6       Hanser Alberto\alberha01  23.0                  TEX         AL   35
# 7       Yonder Alonso*\alonsyo01  29.0                  OAK         AL  156
# 8        Aaron Altherr\altheaa01  25.0                  PHI         NL   57
# 9          Jose Altuve\altuvjo01  26.0                  HOU         AL  161
# 10      Pedro Alvarez*\alvarpe01  29.0                  BAL         AL  109
# 11        Elvis Andrus\andruel01  27.0                  TEX         AL  147
# 12           Nori Aoki*\aokino01  34.0                  SEA         AL  118
# 13      Oswaldo Arcia*\arciaos01  25.0  TOT/MIN/TBR/MIA/SDP  MLB/AL/NL  207
# 14       Nolan Arenado\arenano01  25.0                  COL         NL  160
# 15         Cody Asche*\ascheco01  26.0                  PHI         NL   71
# 16         Alex Avila*\avilaal01  29.0                  CHW         AL   57
# 17          Javier Baez\baezja01  23.0                  CHC         NL  142
# 18       Austin Barnes\barneau01  26.0                  LAD         NL   21
# 19      Brandon Barnes\barnebr02  30.0                  COL         NL   48
# 20    Tucker Barnhart#\barnhtu01  25.0                  CIN         NL  115
# 21       Jose Bautista\bautijo02  35.0                  TOR         AL  116
# 22      Gordon Beckham\beckhgo01  29.0          TOT/ATL/SFG         NL  176
# 23         Tim Beckham\beckhti01  26.0                  TBR         AL   64
# 24        Brandon Belt*\beltbr01  28.0                  SFG         NL  156
# 25       Adrian Beltre\beltrad01  37.0                  TEX         AL  153
# 26        Mookie Betts\bettsmo01  23.0                  BOS         AL  158
# 27   Charlie Blackmon*\blackch02  29.0                  COL         NL  143
# 28      Andres Blanco#\blancan01  32.0                  PHI         NL   90
# 29      Gregor Blanco*\blancgr01  32.0                  SFG         NL  106
# ..                           ...   ...                  ...        ...  ...
# 345    Ronald Torreyes\torrero01  23.0                  NYY         AL   72
# 346       Devon Travis\travide01  25.0                  TOR         AL  101
# 347         Mike Trout\troutmi01  24.0                  LAA         AL  159
# 348        Mark Trumbo\trumbma01  30.0                  BAL         AL  159
# 349    Preston Tucker*\tuckepr01  25.0                  HOU         AL   48
# 350    Troy Tulowitzki\tulowtr01  31.0                  TOR         AL  131
# 351      Justin Turner\turneju01  31.0                  LAD         NL  151
# 352       Justin Upton\uptonju01  28.0                  DET         AL  153
# 353         Juan Uribe\uribeju01  37.0                  CLE         AL   73
# 354       Chase Utley*\utleych01  37.0                  LAD         NL  138
# 355     Luis Valbuena*\valbulu01  30.0                  HOU         AL   90
# 356     Danny Valencia\valenda01  31.0                  OAK         AL  130
# 357    Scott Van Slyke\vanslsc01  29.0                  LAD         NL   52
# 358  Christian Vazquez\vazquch01  25.0                  BOS         AL   57
# 359   Jonathan Villar#\villajo01  25.0                  MIL         NL  156
# 360       Stephen Vogt*\vogtst01  31.0                  OAK         AL  137
# 361        Joey Votto*\vottojo01  32.0                  CIN         NL  158
# 362       Neil Walker#\walkene01  30.0                  NYM         NL  113
# 363     Brett Wallace*\wallabr01  29.0                  SDP         NL  119
# 364       Colin Walsh#\walshco02  26.0                  MIL         NL   38
# 365       Jayson Werth\werthja01  37.0                  WSN         NL  143
# 366      Matt Wieters#\wietema01  30.0                  BAL         AL  124
# 367    Mason Williams*\willima10  24.0                  NYY         AL   12
# 368      Tony Wolters*\wolteto01  24.0                  COL         NL   71
# 369        Kolten Wong*\wongko01  25.0                  STL         NL  121
# 370       David Wright\wrighda03  33.0                  NYM         NL   37
# 371  Christian Yelich*\yelicch01  24.0                  MIA         NL  155
# 372        Chris Young\youngch04  32.0                  BOS         AL   76
# 373     Ryan Zimmerman\zimmery01  31.0                  WSN         NL  115
# 374       Ben Zobrist#\zobribe01  35.0                  CHC         NL  147
#
#       PA   AB    R    H  2B  ...       OPS        OPS+   TB  GDP  HBP  SH  SF  \
# 0    695  624   67  183  32  ...  0.820000  124.000000  292   21   15   0   9
# 1     70   61    6    9   0  ...  0.390000    9.000000    9    0    0   0   1
# 2    256  225   25   49   7  ...  0.607000   53.000000   68    5    4   3   0
# 3    327  297   37   74  18  ...  0.780000  106.000000  140    5    2   0   3
# 4     71   63    3   16   2  ...  0.679000   83.000000   24    0    2   4   0
# 5    308  284   26   62   9  ...  0.564000   46.000000   85    9    4   2   3
# 6     58   56    2    8   1  ...  0.304000  -20.000000    9    1    0   2   0
# 7    532  482   52  122  34  ...  0.683000   88.000000  177   15    1   0   4
# 8    227  198   23   39   6  ...  0.587000   59.000000   57    4    6   0   0
# 9    717  640  108  216  42  ...  0.928000  155.000000  340   15    7   3   7
# 10   376  337   43   84  20  ...  0.826000  117.000000  170    6    0   0   2
# 11   568  506   75  153  31  ...  0.800000  110.000000  222   18    4   4   7
# 12   467  417   63  118  24  ...  0.738000  104.000000  162    9    9   5   1
# 368  230  205   27   53  15  ...  0.723000   81.000000   81    1    0   4   0
# 369  361  313   39   75   7  ...  0.682000   84.000000  111    3    9   0   5
# 370  164  137   18   31   8  ...  0.788000  112.000000   60    0    0   0   0
# 371  659  578   78  172  38  ...  0.859000  135.000000  279   20    4   0   5
# 372  227  203   29   56  18  ...  0.850000  121.000000  101    4    3   0   0
# 373  467  427   60   93  18  ...  0.642000   67.000000  158   12    5   0   6
# 374  631  523   94  142  31  ...  0.831000  121.000000  233   17    4   4   4
#
#      IBB  Pos Summary    Salary
# 0      7         *3/D  13334000
# 1      0        3/9D4   3200000
# 2      0          645    509500
# 3      1            3   1650000
# 4      0         6/45    512500
# 5      3            6    521600
# 6      0       5/64D3    511500
# 7      1        *3/5D   2650000
# 8      2          978    515500
# 9     11        *4D/6   3500000
# 10     1           D5   5750000
# 11     2           *6  15000000
# 12     0          *78   5500000
# 13     0         97/D   3745000
# 14    10           *5   5000000
# 15     0            7    530000
# 16     0          2/D   2500000
# 17     3       546/37    521000
# 18     0         /245    512500
# 19     0         78/9   1000000
# 20     8            2    517500
# 21     1         9D/3  14000000
# 22     2          456   3750000
# 23     0       64/53D    514500
# 24     4         *3/7   6200000
# 25     6          *5D  18000000
# 26     1           *9    566000
# 27     4           *8   3500000
# 28     0       5436/7   1450000
# 29     4          978   3900000
# ..   ...          ...       ...
# 345    0       564/D9    508600
# 346    0          4/D    511200
# 347   12          *8D  16083000
# 348    1        9D/37   9150000
# 349    0         D7/9    515000
# 350    1         *6/D  20000000
# 351    1        *5/D3   5100000
# 352    3        *7/8D  22125000
# 353    1          5/D   4000000
# 354    1         *4/5   7000000
# 355    2         5/34   6125000
# 356    1       593/D7   3150000
# 357    1        79/38   1225000
# 358    1          2/D    513000
# 359    4          654    512900
# 360    3        *2D/3    527500
# 361   15         *3/D  20000000
# 362    3           *4  10550000
# 363    3         53/D   1000000
# 364    0         5/74    507500
# 365    0        *7/D9  21000000
# 366    1         *2/D  15800000
# 367    0        /987D    509700
# 368    2         2/46    507500
# 369    2        4/879   1250000
# 370    0            5  20000000
# 371    4        *78/D   1000000
# 372    0        7/89D   6500000
# 373    1         *3/D  14000000
# 374    6      *479/36  10500000
#
# [375 rows x 30 columns]

# %%
data.shape
# Out:
# (375, 30)

# %%
data.to_csv("data_preprocessing/data_preprocessing_2016.csv")

# %% [markdown]
# ## 2017

# %%
data = pd.read_csv("data/stsal_2017.csv")
data.shape
# Out:
# (701, 30)

# %%
data = data[lambda x: x.Salary > 0]
data = data.reset_index(drop=True)

data.shape
# Out:
# (445, 30)

# %%
i = 0
while i < len(data):
    name = data.loc[i,'Name']
    gamesum = g_sum(i)
    
    for j in range(17, 22):
        data.iloc[i,j] = data.loc[i,'G'] * data.iloc[i,j]
    
    k = i + 1
    while k < len(data):
        if data.loc[k,'Name'] == name:
            
            if data.loc[k,'Tm'] not in data.loc[i,'Tm']:
                data.loc[i,'Tm'] = data.loc[i,'Tm'] + "/" + data.loc[k,'Tm']
            if data.loc[k,'Lg'] not in data.loc[i,'Lg']:
                data.loc[i,'Lg'] = data.loc[i,'Lg'] + "/" + data.loc[k,'Lg']
            
            for l in range(4, 17):
                data.iloc[i,l] += data.iloc[k,l]
                
            for m in range(17, 22):
                data.iloc[i,m] += data.loc[k,'G'] * data.iloc[k,m]
            
            for n in range(22, 28):
                data.iloc[i,n] += data.iloc[k,n]
                
            data.loc[i,'Salary'] += data.loc[k,'Salary']
            
            data = data.drop(data.index[k]).reset_index(drop=True)
        
        else:
            k += 1
            
    for o in range(17, 22):
        data.iloc[i,o] = data.iloc[i,o] / gamesum
    
    i += 1

# %%
data
# Out:
#                                Name   Age           Tm         Lg    G    PA  \
# 0              Jose Abreu\abreujo02  30.0          CHW         AL  156   675
# 1       Cristhian Adames#\adamecr01  25.0          COL         NL   12    14
# 2           Jesus Aguilar\aguilje01  27.0          MIL         NL  133   311
# 3              Nick Ahmed\ahmedni01  27.0          ARI         NL   53   178
# 4    Arismendy Alcantara#\alcanar01  25.0          CIN         NL   70   108
# 5        Abraham Almonte#\almonab01  28.0          CLE         AL   69   195
# 6           Albert Almora\almoral01  23.0          CHC         NL  132   323
# 7          Yonder Alonso*\alonsyo01  30.0  TOT/OAK/SEA         AL  284  1042
# 8           Aaron Altherr\altheaa01  26.0          PHI         NL  107   412
# 9             Jose Altuve\altuvjo01  27.0          HOU         AL  153   662
# 10        Alexi Amarista*\amarial01  28.0          COL         NL   96   176
# 11           Tim Anderson\anderti01  24.0          CHW         AL  146   606
# 12           Elvis Andrus\andruel01  28.0          TEX         AL  158   689
# 13              Nori Aoki*\aokino01  35.0      TOR/NYM      AL/NL   39   150
# 14          Orlando Arcia\arciaor01  22.0          MIL         NL  153   548
# 15          Nolan Arenado\arenano01  26.0          COL         NL  159   680
# 16            Cody Asche*\ascheco01  27.0          CHW         AL   19    62
# 17           Tyler Austin\austity01  25.0          NYY         AL   20    46
# 18            Alex Avila*\avilaal01  30.0  TOT/DET/CHC  MLB/AL/NL  224   752
# 19            Mike Aviles\avilemi01  36.0          MIA         NL   37    97
# 20             Javier Baez\baezja01  24.0          CHC         NL  145   508
# 21             Jett Bandy\bandyje01  27.0          MIL         NL   60   188
# 22          Austin Barnes\barneau01  27.0          LAD         NL  102   262
# 23          Darwin Barney\barneda01  31.0          TOR         AL  129   362
# 24       Tucker Barnhart#\barnhtu01  26.0          CIN         NL  121   423
# 25          Jose Bautista\bautijo02  36.0          TOR         AL  157   686
# 26            Tim Beckham\beckhti01  27.0  TOT/TBR/BAL         AL  274  1150
# 27              Josh Bell#\belljo02  24.0          PIT         NL  159   620
# 28           Brandon Belt*\beltbr01  29.0          SFG         NL  104   451
# 29        Carlos Beltran#\beltrca01  40.0          HOU         AL  129   509
# ..                              ...   ...          ...        ...  ...   ...
# 359          Luis Torrens\torrelu01  21.0          SDP         NL   56   139
# 360       Ronald Torreyes\torrero01  24.0          NYY         AL  108   336
# 361          Devon Travis\travide01  26.0          TOR         AL   50   197
# 362            Mike Trout\troutmi01  25.0          LAA         AL  114   507
# 363           Mark Trumbo\trumbma01  31.0          BAL         AL  146   603
# 364       Troy Tulowitzki\tulowtr01  32.0          TOR         AL   66   260
# 365         Justin Turner\turneju01  32.0          LAD         NL  130   543
# 366         Stuart Turner\turnest01  25.0          CIN         NL   37    89
# 367           Trea Turner\turnetr01  24.0          WSN         NL   98   447
# 368          Chase Utley*\utleych01  38.0          LAD         NL  127   353
# 369        Luis Valbuena*\valbulu01  31.0          LAA         AL  117   401
# 370        Danny Valencia\valenda01  32.0          SEA         AL  130   500
# 371       Scott Van Slyke\vanslsc01  30.0          LAD         NL   29    48
# 372        Kennys Vargas#\vargake01  26.0          MIN         AL   78   264
# 373     Christian Vazquez\vazquch01  26.0          BOS         AL   99   345
# 374      Jonathan Villar#\villajo01  26.0          MIL         NL  122   436
# 375           Joey Votto*\vottojo01  33.0          CIN         NL  162   707
# 376          Neil Walker#\walkene01  31.0  TOT/NYM/MIL         NL  222   896
# 377          Rickie Weeks\weeksri01  34.0          TBR         AL   37   112
# 378          Joey Wendle*\wendljo01  27.0          OAK         AL    8    14
# 379          Jayson Werth\werthja01  38.0          WSN         NL   70   289
# 380         Matt Wieters#\wietema01  31.0          WSN         NL  123   465
# 381        Mac Williamson\willima11  26.0          SFG         NL   28    73
# 382         Tony Wolters*\wolteto01  25.0          COL         NL   83   266
# 383           Kolten Wong*\wongko01  26.0          STL         NL  108   411
# 384     Christian Yelich*\yelicch01  25.0          MIA         NL  156   695
# 385           Chris Young\youngch04  33.0          BOS         AL   90   276
# 386        Ryan Zimmerman\zimmery01  32.0          WSN         NL  144   576
# 387          Ben Zobrist#\zobribe01  36.0          CHC         NL  128   496
# 388           Mike Zunino\zuninmi01  26.0          SEA         AL  124   435
#
#        AB    R    H  2B  ...       OPS        OPS+   TB  GDP  HBP  SH  SF  \
# 0     621   95  189  43  ...  0.906000  141.000000  343   21   15   0   4
# 1      13    1    0   0  ...  0.071000  -80.000000    0    0    0   0   0
# 2     279   40   74  15  ...  0.837000  114.000000  141    8    4   0   3
# 3     167   24   42   8  ...  0.717000   79.000000   70    6    1   0   0
# 4     105   13   18   3  ...  0.435000   12.000000   26    2    0   1   0
# 5     172   26   40   8  ...  0.681000   78.000000   63    2    1   1   1
# 6     299   39   89  18  ...  0.782000  100.000000  133    8    0   3   2
# 7     902  144  240  44  ...  0.865768  133.802817  452   18    4   0   0
# 8     372   58  101  24  ...  0.856000  122.000000  192   12    7   0   1
# 9     590  112  204  39  ...  0.957000  160.000000  323   19    9   1   4
# 10    168   22   40  10  ...  0.620000   51.000000   59    5    0   1   0
# 11    587   72  151  26  ...  0.679000   81.000000  236   13    3   2   1
# 12    643  100  191  44  ...  0.808000  105.000000  303   18    3   1   4
# 13    134   20   38   8  ...  0.787615  109.307692   57    1    1   0   1
# 14    506   56  140  17  ...  0.731000   89.000000  206   10    1   2   3
# 386   524   90  159  33  ...  0.930000  134.000000  300   16    3   0   5
# 387   435   58  101  20  ...  0.693000   79.000000  163   13    2   2   3
# 388   387   52   97  25  ...  0.840000  125.000000  197    8    8   0   1
#
#      IBB  Pos Summary    Salary
# 0      6          *3D  10825000
# 1      0         /346    540000
# 2      1         3/D5    536000
# 3      3            6    566000
# 4      0      4/89657    538000
# 5      0        97/8D    544200
# 6      1         8/79    552000
# 7     12         *3/D  12000000
# 8      2          798    538500
# 9      3         *4/D   4500000
# 10     0      46/8975   1100000
# 11     0           *6    850000
# 12     0         *6/D  15000000
# 13     0         /978  11000000
# 14     9           *6    538100
# 15     9           *5  11750000
# 16     1        D/357    535000
# 17     0         /39D    544000
# 18     4         23/D   6000000
# 19     2       6/4539    535000
# 20    15       46/539    609000
# 21     0            2    539800
# 22     1        24/5D    540000
# 23     0       456/7D   2887500
# 24    11           *2    575000
# 25     3       *9D/53  18000000
# 26     0       *64/5D   2655000
# 27     4         *3/D    549000
# 28     2         37/9   4000000
# 29     3         D7/9  16000000
# ..   ...          ...       ...
# 359    3            2    535000
# 360    0       465/D9    561900
# 361    0            4    545200
# 362   15          8/D  20083000
# 363    0       *D9/35  11500000
# 364    1            6  20000000
# 365    5         *5/D  13000000
# 366    0            2    535000
# 367    0            6    554900
# 368    0         43/D   2000000
# 369    1         53/D   6500000
# 370    0        *39/5   5500000
# 371    1        7/389   1325000
# 372    1           3D    540000
# 373    0         2/5D    561000
# 374    1         4/8D    554500
# 375   20           *3  22000000
# 376    4         43/5  51600000
# 377    0           D3   1500000
# 378    1           /4    535000
# 379    1         79/D  21000000
# 380    4           *2  10500000
# 381    1         9/7D    539000
# 382    9         2/45    540000
# 383   11            4   2500000
# 384    4           *8   3500000
# 385    0         7D/9   6500000
# 386    1         *3/D  14000000
# 387    2       479/36  16500000
# 388    0         *2/D    570000
#
# [389 rows x 30 columns]

# %%
data.shape
# Out:
# (389, 30)

# %%
data.to_csv("data_preprocessing/data_preprocessing_2017.csv")

# %% [markdown]
# ## 2018

# %%
data = pd.read_csv("data/stsal_2018.csv")
data.shape
# Out:
# (698, 30)

# %%
data = data[lambda x: x.Salary > 0]
data = data.reset_index(drop=True)

data.shape
# Out:
# (407, 30)

# %%
i = 0
while i < len(data):
    name = data.loc[i,'Name']
    gamesum = g_sum(i)
    
    for j in range(17, 22):
        data.iloc[i,j] = data.loc[i,'G'] * data.iloc[i,j]
    
    k = i + 1
    while k < len(data):
        if data.loc[k,'Name'] == name:
            
            if data.loc[k,'Tm'] not in data.loc[i,'Tm']:
                data.loc[i,'Tm'] = data.loc[i,'Tm'] + "/" + data.loc[k,'Tm']
            if data.loc[k,'Lg'] not in data.loc[i,'Lg']:
                data.loc[i,'Lg'] = data.loc[i,'Lg'] + "/" + data.loc[k,'Lg']
            
            for l in range(4, 17):
                data.iloc[i,l] += data.iloc[k,l]
                
            for m in range(17, 22):
                data.iloc[i,m] += data.loc[k,'G'] * data.iloc[k,m]
            
            for n in range(22, 28):
                data.iloc[i,n] += data.iloc[k,n]
                
            data.loc[i,'Salary'] += data.loc[k,'Salary']
            
            data = data.drop(data.index[k]).reset_index(drop=True)
        
        else:
            k += 1
            
    for o in range(17, 22):
        data.iloc[i,o] = data.iloc[i,o] / gamesum
    
    i += 1

# %%
data
# Out:
#                                Name   Age           Tm      Lg    G   PA   AB  \
# 0        Ronald Acuna Jr.\acunaro01  20.0          ATL      NL  111  487  433
# 1              Lane Adams\adamsla01  28.0          ATL      NL   26   29   25
# 2             Matt Adams*\adamsma01  29.0  TOT/WSN/STL      NL  242  674  612
# 3         Ehire Adrianza#\adriaeh01  28.0          MIN      AL  114  366  335
# 4           Jesus Aguilar\aguilje01  28.0          MIL      NL  149  566  492
# 5              Nick Ahmed\ahmedni01  28.0          ARI      NL  153  564  516
# 6           Ozzie Albies#\albieoz01  21.0          ATL      NL  158  684  639
# 7            Jorge Alfaro\alfarjo01  25.0          PHI      NL  108  377  344
# 8           Albert Almora\almoral01  24.0          CHC      NL  152  479  444
# 9          Yonder Alonso*\alonsyo01  31.0          CLE      AL  145  574  516
# 10          Aaron Altherr\altheaa01  27.0          PHI      NL  105  285  243
# 11            Jose Altuve\altuvjo01  28.0          HOU      AL  137  599  534
# 12         Pedro Alvarez*\alvarpe01  31.0          BAL      AL   45  127  111
# 13         Brian Anderson\anderbr06  25.0          MIA      NL  156  670  590
# 14           Tim Anderson\anderti01  25.0          CHW      AL  153  606  567
# 15           Elvis Andrus\andruel01  29.0          TEX      AL   97  428  395
# 16          Orlando Arcia\arciaor01  23.0          MIL      NL  119  366  348
# 17          Nolan Arenado\arenano01  27.0          COL      NL  156  673  590
# 18         Carlos Asuaje*\asuajca01  26.0          SDP      NL   79  218  189
# 19             Javier Baez\baezja01  25.0          CHC      NL  160  645  606
# 20             Jett Bandy\bandyje01  28.0          MIL      NL   24   71   64
# 21          Austin Barnes\barneau01  28.0          LAD      NL  100  238  200
# 22       Tucker Barnhart#\barnhtu01  27.0          CIN      NL  138  522  460
# 23         Gordon Beckham\beckhgo01  31.0          SEA      AL   22   50   44
# 24            Tim Beckham\beckhti01  28.0          BAL      AL   96  402  369
# 25              Josh Bell#\belljo02  25.0          PIT      NL  148  583  501
# 26        Cody Bellinger*\bellico01  22.0          LAD      NL  162  632  557
# 27           Brandon Belt*\beltbr01  30.0          SFG      NL  112  456  399
# 28          Adrian Beltre\beltrad01  39.0          TEX      AL  119  481  433
# 29     Andrew Benintendi*\beninan01  23.0          BOS      AL  148  661  579
# ..                              ...   ...          ...     ...  ...  ...  ...
# 322          Blake Trahan\trahabl01  24.0          CIN      NL   11   14   14
# 323          Jose Trevino\trevijo01  25.0          TEX      AL    3    8    8
# 324            Mike Trout\troutmi01  26.0          LAA      AL  140  608  471
# 325          Kyle Tucker*\tuckeky01  21.0          HOU      AL   28   72   64
# 326       Preston Tucker*\tuckepr01  27.0  TOT/ATL/CIN      NL  194  368  332
# 327         Justin Turner\turneju01  33.0          LAD      NL  103  426  365
# 328           Trea Turner\turnetr01  25.0          WSN      NL  162  740  664
# 329           Gio Urshela\urshegi01  26.0          TOR      AL   19   46   43
# 330          Chase Utley*\utleych01  39.0          LAD      NL   87  187  164
# 331           Pat Valaika\valaipa01  25.0          COL      NL   68  133  122
# 332      Ildemaro Vargas#\vargail01  26.0          ARI      NL   14   20   19
# 333        Engelb Vielma#\vielmen01  24.0          BAL      AL    6    8    7
# 334  Christian Villanueva\villach01  27.0          SDP      NL  110  384  351
# 335      Jonathan Villar#\villajo01  27.0      TOT/MIL  MLB/NL  228  794  723
# 336              Luke Voit\voitlu01  27.0          NYY      AL   39  148  132
# 337           Joey Votto*\vottojo01  34.0          CIN      NL  145  623  503
# 338      Christian Walker\walkech02  27.0          ARI      NL   37   53   49
# 339          Neil Walker#\walkene01  32.0          NYY      AL  113  398  347
# 340           Tyler White\whitety01  27.0          HOU      AL   66  237  210
# 341       Mason Williams*\willima10  26.0          CIN      NL   51  132  123
# 342          Bobby Wilson\wilsobo02  35.0          MIN      AL   47  151  135
# 343        Patrick Wisdom\wisdopa01  26.0          STL      NL   32   58   50
# 344         Tony Wolters*\wolteto01  26.0          COL      NL   74  216  182
# 345           Kolten Wong*\wongko01  27.0          STL      NL  127  407  353
# 346          Austin Wynns\wynnsau01  27.0          BAL      AL   42  118  110
# 347     Christian Yelich*\yelicch01  26.0          MIL      NL  147  651  574
# 348          Mark Zagunis\zagunma01  25.0          CHC      NL    5    6    5
# 349       Bradley Zimmer*\zimmebr01  25.0          CLE      AL   34  114  106
# 350        Ryan Zimmerman\zimmery01  33.0          WSN      NL   85  323  288
# 351          Ben Zobrist#\zobribe01  37.0          CHC      NL  139  520  455
#
#        R    H  2B  ...       OPS        OPS+   TB  GDP  HBP  SH  SF  IBB  \
# 0     78  127  26  ...  0.917000  143.000000  239    4    6   0   3    2
# 1     10    6   1  ...  0.865000  129.000000   13    1    0   0   0    0
# 2     84  146  20  ...  0.779525  103.132231  292   12    8   0   0    6
# 3     42   84  23  ...  0.680000   85.000000  127    4    1   4   2    2
# 4     80  135  25  ...  0.890000  135.000000  265   19    6   0  10    3
# 5     61  121  33  ...  0.700000   83.000000  212   15    2   1   5    2
# 6    105  167  40  ...  0.757000  101.000000  289    9    5   1   3    0
# 7     35   90  16  ...  0.731000   95.000000  140    2   14   0   1    6
# 8     62  127  24  ...  0.701000   86.000000  168   12    3   2   6    1
# 9     64  129  19  ...  0.738000   98.000000  217   10    2   0   5    1
# 10    28   44  11  ...  0.628000   69.000000   81   13    4   0   2    0
# 11    84  169  29  ...  0.837000  130.000000  241   17    6   3   1    4
# 12    18   20   2  ...  0.698000   90.000000   46    2    0   0   0    0
# 13    87  161  34  ...  0.757000  110.000000  236   18   16   0   2    2
# 14    77  136  28  ...  0.687000   87.000000  230   15    4   2   3    2
# 15    53  101  20  ...  0.675000   78.000000  145    8    3   0   2    0
# 16    32   82  16  ...  0.576000   55.000000  107    9    1   1   1    0
# 17   104  175  38  ...  0.935000  133.000000  331   16    3   1   6   10
# 18    15   37   8  ...  0.566000   59.000000   53    5    1   1   3    1
# 19   101  176  40  ...  0.881000  129.000000  336   10    5   1   4    8
# 20     5   12   2  ...  0.533000   44.000000   17    0    4   0   0    0
# 21    32   41   5  ...  0.619000   72.000000   58    7    6   1   0    4
# 22    50  114  21  ...  0.699000   88.000000  171   13    2   3   3    2
# 23     3    8   1  ...  0.455000   31.000000    9    1    0   2   0    0
# 24    45   85  17  ...  0.661000   81.000000  138   10    3   1   2    0
# 25    74  131  31  ...  0.768000  111.000000  206   12    0   0   5    2
# 26    84  145  28  ...  0.814000  120.000000  262    7    3   0   3    9
# 27    50  101  18  ...  0.756000  110.000000  165    2    6   0   2    6
# 28    49  118  23  ...  0.763000   99.000000  188   13    6   0   8    2
# 29   103  168  41  ...  0.830000  123.000000  269    9    2   2   7    1
# ..   ...  ...  ..  ...       ...         ...  ...  ...  ...  ..  ..  ...
# 322    2    3   0  ...  0.429000   16.000000    3    0    0   0   0    0
# 323    0    2   0  ...  0.500000   33.000000    2    1    0   0   0    0
# 324  101  147  24  ...  1.088000  198.000000  296    5   10   0   4   25
# 325   10    9   2  ...  0.439000   23.000000   13    1    2   0   0    0
# 326   38   76  22  ...  0.682490   82.298969  134    4    8   0   2    0
# 327   62  114  31  ...  0.924000  151.000000  189   10   12   0   2    3
# 328  103  180  27  ...  0.760000  100.000000  276    7    5   2   0    3
# 329    7   10   1  ...  0.608000   68.000000   14    1    1   0   0    0
# 330   18   35  10  ...  0.610000   68.000000   50    3    5   0   1    2
# 331    8   19   5  ...  0.460000   16.000000   30    4    0   2   0    0
# 332    2    4   0  ...  0.618000   61.000000    7    1    0   0   0    0
# 333    1    1   0  ...  0.393000   14.000000    1    0    0   0   0    0
# 334   42   83  15  ...  0.750000  106.000000  158   12    9   0   1    0
# 335   80  188  24  ...  0.702895   89.947368  276   22    7   1   3    0
# 336   28   44   5  ...  1.095000  193.000000   91    3    1   0   0    0
# 337   67  143  28  ...  0.837000  126.000000  211   15    9   0   3    6
# 338    6    8   2  ...  0.614000   59.000000   19    1    1   0   0    0
# 339   48   76  12  ...  0.664000   82.000000  123    3    5   0   4    3
# 340   27   58  12  ...  0.888000  140.000000  112    1    2   0   1    0
# 341   10   36   5  ...  0.729000   95.000000   49    5    0   2   0    1
# 342   12   24   8  ...  0.523000   43.000000   38    6    0   2   2    0
# 343   11   13   1  ...  0.882000  138.000000   26    1    2   0   0    0
# 344   19   31   4  ...  0.577000   48.000000   52    6    6   0   2    2
# 345   41   88  18  ...  0.720000   97.000000  137    6   14   6   3    3
# 346   16   28   2  ...  0.669000   83.000000   42    7    0   3   0    0
# 347  118  187  34  ...  1.000000  164.000000  343   14    7   0   2    2
# 348    0    2   1  ...  1.100000  192.000000    3    0    0   0   0    0
# 349   14   24   5  ...  0.611000   65.000000   35    1    1   0   0    0
# 350   33   76  21  ...  0.824000  114.000000  140   10    3   0   2    1
# 351   67  139  28  ...  0.817000  117.000000  200    8    2   1   7    1
#
#      Pos Summary    Salary
# 0          78/9D    545000
# 1           /987    575000
# 2          37/D9  12000000
# 3        653/47D   1000000
# 4          *3/5D    557200
# 5             *6   1275000
# 6             *4    555000
# 7            2/5    547000
# 8           *8/7    584500
# 9           *3/D   7000000
# 10          98/7    561000
# 11          *4/D   9000000
# 12          D/53   1000000
# 13            95    545000
# 14          *6/D   1000000
# 15             6  15250000
# 16            *6    559600
# 17          *5/D  17750000
# 18           4/5    550100
# 19         465/3    657000
# 20             2    550700
# 21            24    555000
# 22           *23   4437500
# 23         4/56D    100000
# 24         65/D4   3350000
# 25          *3/D    572500
# 26        *38/97    585000
# 27           3/7  17200000
# 28            5D  18000000
# 29           *78    620500
# ..           ...       ...
# 322         /645   1450000
# 323           /2  34083000
# 324          *8D  12500000
# 325         7/98    565000
# 326         7/9D  13695000
# 327          5/D    577200
# 328           *6  16000000
# 329         5/6D   1000000
# 330          4/3    550000
# 331        43/56   8000000
# 332         /546   1425000
# 333          /46    548500
# 334        5/634   2550000
# 335          *46   5100000
# 336         3/D9  25000000
# 337         *3/D    551300
# 338         /3D7   4000000
# 339      3459/D7    545000
# 340           3D  10500000
# 341         98/7    553000
# 342            2    545000
# 343          5/3    550000
# 344        2/475   4000000
# 345           *4  20000000
# 346          2/D   7000000
# 347         *798   2000000
# 348           /9    551200
# 349            8  14000000
# 350            3  16500000
# 351       497/3D   2975000
#
# [352 rows x 30 columns]

# %%
data.shape
# Out:
# (352, 30)

# %%
data.to_csv("data_preprocessing/data_preprocessing_2018.csv")

# %% [markdown]
# ## 2019

# %%
data = pd.read_csv("data/stsal_2019.csv", encoding = 'cp949')
data.shape
# Out:
# (687, 30)

# %%
data = data[lambda x: x.Salary > 0]
data = data.reset_index(drop=True)

data.shape
# Out:
# (447, 30)

# %%
i = 0
while i < len(data):
    name = data.loc[i,'Name']
    gamesum = g_sum(i)
    
    for j in range(17, 22):
        data.iloc[i,j] = data.loc[i,'G'] * data.iloc[i,j]
    
    k = i + 1
    while k < len(data):
        if data.loc[k,'Name'] == name:
            
            if data.loc[k,'Tm'] not in data.loc[i,'Tm']:
                data.loc[i,'Tm'] = data.loc[i,'Tm'] + "/" + data.loc[k,'Tm']
            if data.loc[k,'Lg'] not in data.loc[i,'Lg']:
                data.loc[i,'Lg'] = data.loc[i,'Lg'] + "/" + data.loc[k,'Lg']
            
            for l in range(4, 17):
                data.iloc[i,l] += data.iloc[k,l]
                
            for m in range(17, 22):
                data.iloc[i,m] += data.loc[k,'G'] * data.iloc[k,m]
            
            for n in range(22, 28):
                data.iloc[i,n] += data.iloc[k,n]
                
            data.loc[i,'Salary'] += data.loc[k,'Salary']
            
            data = data.drop(data.index[k]).reset_index(drop=True)
        
        else:
            k += 1
            
    for o in range(17, 22):
        data.iloc[i,o] = data.iloc[i,o] / gamesum
    
    i += 1

# %%
data

# %%
data.shape

# %%
data.to_csv("data_preprocessing/data_preprocessing_2019.csv")
